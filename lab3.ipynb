# %% [markdown]
# <a href="https://colab.research.google.com/github/jojoagh/python_lab/blob/master/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('exercise_dataset.csv')
data.describe()
# Out:
#                 ID  Calories Burn  Dream Weight  Actual Weight          Age  \
# count  3864.000000    3864.000000   3864.000000    3864.000000  3864.000000
# mean   1932.500000     301.861806     75.139263      75.188440    39.621118
# std    1115.585048     115.828604     14.545824      14.845511    12.521721
# min       1.000000     100.009403     50.001984      45.783747    18.000000
# 25%     966.750000     202.168837     62.373585      62.476906    29.000000
# 50%    1932.500000     299.742508     75.522136      75.544407    40.000000
# 75%    2898.250000     404.143688     87.707989      88.105767    51.000000
# max    3864.000000     499.859262     99.985355     104.309600    60.000000
#
#           Duration   Heart Rate          BMI  Exercise Intensity
# count  3864.000000  3864.000000  3864.000000         3864.000000
# mean     40.190994   139.777950    26.801977            5.457298
# std      11.765957    23.447528     4.746745            2.850896
# ...

# %%
data.head()
# Out:
#    ID     Exercise  Calories Burn  Dream Weight  Actual Weight  Age  Gender  \
# 0   1   Exercise 2     286.959851     91.892531      96.301115   45    Male
# 1   2   Exercise 7     343.453036     64.165097      61.104668   25    Male
# 2   3   Exercise 4     261.223465     70.846224      71.766724   20    Male
# 3   4   Exercise 5     127.183858     79.477008      82.984456   33    Male
# 4   5  Exercise 10     416.318374     89.960226      85.643174   29  Female
#
#    Duration  Heart Rate        BMI Weather Conditions  Exercise Intensity
# 0        37         170  29.426275              Rainy                   5
# 1        43         142  21.286346              Rainy                   5
# 2        20         148  27.899592             Cloudy                   4
# 3        39         170  33.729552              Sunny                  10
# 4        34         118  23.286113             Cloudy                   3

# %% [markdown]
# task 4

# %%
import matplotlib.pyplot as plt
data['Age'].plot.hist()
plt.title('Histogram for Age frequency')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import matplotlib.pyplot as plt
plt.bar(data['Age'],data['Duration'])
plt.title('Age vs Duration bar graph')
plt.xlabel('Age')
plt.ylabel('Duration')
# Out:
# Text(0, 0.5, 'Duration')

# %%
import matplotlib.pyplot as plt
plt.scatter(data['Dream Weight'],data['Actual Weight'])
plt.title('Dream Weight vs Actual Weight scatter graph')
plt.xlabel('Dream Weight')
plt.ylabel('Actual Weight')
# Out:
# Text(0, 0.5, 'Actual Weight')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(y = data['Age'])
plt.title('Age box plot')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(y = data['Age'] , x = data['Gender'])
plt.title('box plot')
plt.xlabel('Gender')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %% [markdown]
# task 5

# %%
import matplotlib.pyplot as plt
import seaborn as sns
f1 = plt.figure()
sns.boxplot(y = data['Age'])
plt.title('Age box plot')
plt.ylabel('Age')
f1.savefig('age_boxplot.png')

# %% [markdown]
# task 6

# %%
import matplotlib.pyplot as plt
plt.bar(data['Age'],data['Duration'], color = "red")
plt.title('Age vs Duration bar graph')
plt.xlabel('Age')
plt.ylabel('Duration')
# Out:
# Text(0, 0.5, 'Duration')

# %% [markdown]
# task 7

# %%
import seaborn as sns
sns.set_theme()
sns.scatterplot(x=data['Age'], y=data['BMI'])
plt.figure(figsize=(10, 5))

# %%
import seaborn as sns
sns.set_theme()
sns.scatterplot(x=data['Age'], y=data['BMI'], data = data , hue = 'Gender')
plt.figure(figsize=(10, 5))

# %% [markdown]
# task 8

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
sns.boxplot(y = data['Age'])
plt.title('Age box plot')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
sns.boxplot(y = data['Age'] , x = data['Gender'])
plt.title('box plot')
plt.xlabel('Gender')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x = data['Exercise'] , y = data['Calories Burn'])
plt.title('box plot')
plt.xlabel('Excercise')
plt.ylabel('Calories Burn')
# Out:
# Text(0, 0.5, 'Calories Burn')

# %% [markdown]
# task 9

# %%
corr = data.corr()
sns.heatmap(corr,annot = True, cmap = 'Blues')
plt.title('data Heatmap')
# Out:
# <ipython-input-73-4d49fc5fdf6a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
# Text(0.5, 1.0, 'data Heatmap')

# %% [markdown]
# task 10

# %%
from sklearn.model_selection import train_test_split

X = data.drop('Exercise Intensity', axis = 1)
y = data['Exercise Intensity']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 12)
X_train, X_Validation, y_train, y_Validation = train_test_split(X_train, y_train, test_size=0.25,random_state = 12)
